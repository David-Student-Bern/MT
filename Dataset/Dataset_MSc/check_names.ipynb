# %% [markdown]
# I want to check if all the column names from the .json file are in the .parquet

# %%
import pandas as pd
import json

# --- Load DataFrame ---
# local_head = 'C:/Users/david/Documents/David/Unibe/Master_Thesis/'
local_head = '/home/dschwarz/Documents/MT/'

# Load Data from parquet files
GFOC_dir = local_head+'Dataset/Dataset_MSc/GFOC_RDCDFI.parquet'
GFOC_data = pd.read_parquet(GFOC_dir)
GFOC_data = GFOC_data.reset_index()

SWMA_dir = local_head+'Dataset/Dataset_MSc/SWMA_RDAWFI.parquet'
SWMA_data = pd.read_parquet(SWMA_dir)
SWMA_data = SWMA_data.reset_index()


# --- IGNORE ---
# Deprecated: csv files are no longer used as updated parquet files are available
# Load the GOFC data more efficiently
# GFOC_dir = local_head+'Dataset/Dataset_MSc/GFOC_RDCDFI.csv'
# GFOC_data = pd.read_csv(GFOC_dir, low_memory=True)

# Load the SWMA data more efficiently
# SWMA_dir = local_head+'Dataset/Dataset_MSc/SWMA_RDAWFI.csv'
# SWMA_data = pd.read_csv(SWMA_dir, low_memory=True)

# %%
# Save DataFrames columns as txt files with each column on a new line
with open(local_head+'Dataset/Dataset_MSc/GFOC_columns.txt', 'w') as f:
    for col in GFOC_data.columns:
        f.write(col + '\n')

with open(local_head+'Dataset/Dataset_MSc/SWMA_columns.txt', 'w') as f:
    for col in SWMA_data.columns:
        f.write(col + '\n')

# %% [markdown]
# it seems like the 'time' column was ditched or renamed. Maybe to 'T0 [s]' but that would be weird.

# %% [markdown]
# # The following code does no longer work with the parquet files...

# %%
# --- Load JSON column documentation ---
with open("data_doc_all.json", "r") as f:
    data_doc = json.load(f)

# --- Extract all documented column names ---
documented_columns = set()
for section in data_doc.values():
    for entry in section:
        documented_columns.add(entry["Name"])

# --- Compare with DataFrame columns ---
print("GFOC_RDCDFI.parquet and SWMA_RDAWFI.parquet Column Documentation Check")
print("GFOC_RDCDFI.parquet:")
df = GFOC_data.copy()
df_columns = set(df.columns)

missing_from_df = documented_columns - df_columns
extra_in_df = df_columns - documented_columns

# --- Output results ---
print("🟥 Columns documented but missing from DataFrame:")
for col in sorted(missing_from_df):
    print(f" - {col}")

print("\n🟦 Columns in DataFrame but not documented:")
for col in sorted(extra_in_df):
    print(f" - {col}")

print("\nSWMA_RDAWFI.parquet:")
df = SWMA_data.copy()
df_columns = set(df.columns)

missing_from_df = documented_columns - df_columns
extra_in_df = df_columns - documented_columns

# --- Output results ---
print("🟥 Columns documented but missing from DataFrame:")
for col in sorted(missing_from_df):
    print(f" - {col}")

print("\n🟦 Columns in DataFrame but not documented:")
for col in sorted(extra_in_df):
    print(f" - {col}")
# Out:
# GFOC_RDCDFI.parquet and SWMA_RDAWFI.parquet Column Documentation Check
# GFOC_RDCDFI.parquet:
# 🟥 Columns documented but missing from DataFrame:
#  - Bx GSM
#  - DoY
#  - Dst (nT) (LASP)
#  - VX_IN
#  - VY_IN
#  - VZ_IN
#  - X_EF
#  - X_IN
#  - Y_EF
#  - Y_IN
#  - Z_EF
#  - Z_IN
#  - air_x [nm/s^2]
#  - air_y [nm/s^2]
#  - air_z [nm/s^2]
#  - beta_sun
#  - columns with _c
#  - h_ell
#  - intercept
#  - is_maneuver_day
#  - is_maneuver_day_extended
#  - is_maneuver_period_generic
#  - is_missing_day
#  - is_missing_day_extended
#  - is_outlier_maneuver_day
#  - lat_ell
#  - lat_sph
#  - lon_ell
#  - lon_sph
#  - mean_altitude
#  - r
#  - res
#  - res_std
#  - residual
#  - se_orbital_decay
#  - seasonal_1
#  - seasonal_2
#  - seasonal_3
#  - seasonal_4
#  - slope
#  - time
#  - trend
#  - u_sat
#  - u_sun
#  - unresolved
#
# 🟦 Columns in DataFrame but not documented:
#  - Approximate Distance to SEL (Re)
#  - Bartels Rotation Number
#  - Bz GSE_intercept
#  - Bz GSE_res
#  - Bz GSE_res_std
#  - Bz GSE_se_slope
#  - Bz GSE_slope
#  - Electric Field (Mv/m)_intercept
#  - Electric Field (Mv/m)_res
#  - Electric Field (Mv/m)_res_std
#  - Electric Field (Mv/m)_se_slope
#  - Electric Field (Mv/m)_slope
#  - Flow Speed (km/s_intercept
#  - Flow Speed (km/s_res
#  - Flow Speed (km/s_res_std
#  - Flow Speed (km/s_se_slope
#  - Flow Speed (km/s_slope
#  - L1 Distance Gradient
#  - L1 Distance Gradient Residuals
#  - Position Anomaly
#  - Proton density (n/cc)_intercept
#  - Proton density (n/cc)_res
#  - Proton density (n/cc)_res_std
#  - Proton density (n/cc)_se_slope
#  - Proton density (n/cc)_slope
#  - Solar Cycle
#  - VX_IN [m/s]
#  - VY_IN [m/s]
#  - VZ_IN [m/s]
#  - X_EF [m]
#  - X_IN [m]
#  - Y_EF [m]
#  - Y_IN [m]
#  - Z_EF [m]
#  - Z_IN [m]
#  - aDot_m_s
#  - a_m
#  - air_R [nm/s^2]
#  - air_S [nm/s^2]
#  - air_W [nm/s^2]
#  - beta_sun [deg]
#  - emi_R [nm/s^2]
#  - emi_S [nm/s^2]
#  - emi_W [nm/s^2]
#  - gp_R [mm/s^2]
#  - gp_S [mm/s^2]
#  - gp_W [mm/s^2]
#  - h_ell [m]
#  - lat_ell [deg]
#  - lat_sph [deg]
#  - lon_ell [deg]
#  - lon_sph [deg]
#  - orbital_decay_tle
#  - r [m]
#  - ref_R [nm/s^2]
#  - ref_S [nm/s^2]
#  - ref_W [nm/s^2]
#  - srp_R [nm/s^2]
#  - srp_S [nm/s^2]
#  - srp_W [nm/s^2]
#  - u_sat [deg]
#  - u_sun [deg]
#  - |avg B|_intercept
#  - |avg B|_res
#  - |avg B|_res_std
#  - |avg B|_se_slope
#  - |avg B|_slope
#
# SWMA_RDAWFI.parquet:

# %% [markdown]
# ## Check missing Columns
#
# Missing/differnent columns are the same for GFOC and SWMA
#
# Emoji convention
# - ✅: is in the database but has a different name than in the json
# - ⛔ is not in the database
# - ⚪️ is in database but not in json
#
# 🟥 Columns documented but missing from DataFrame:
#  - ✅ Bx GSM **Same as Bx GSE**
#  - ⛔ F30 (LASP) **Not in database**
#  - ✅ VX_IN
#  - ✅ VY_IN
#  - ✅ VZ_IN
#  - ✅ X_EF
#  - ✅ X_IN
#  - ✅ Y_EF
#  - ✅ Y_IN
#  - ✅ Z_EF
#  - ✅ Z_IN
#  - ✅ beta_sun
#  - ⛔ columns with _c
#  - ✅ h_ell
#  - ✅ is_outlier_maneuver_day
#  - ✅ lat_ell
#  - ✅ lat_sph
#  - ✅ lon_ell
#  - ✅ lon_sph
#  - ✅ r
#  - ✅ u_sat
#  - ✅ u_sun
#
# 🟦 Columns in DataFrame but not documented:
#  - Approximate Distance to SEL (Re)
#  - ✅ VX_IN [m/s]
#  - ✅ VY_IN [m/s]
#  - ✅ VZ_IN [m/s]
#  - ✅ X_EF [m]
#  - ✅ X_IN [m]
#  - ✅ Y_EF [m]
#  - ✅ Y_IN [m]
#  - ✅ Z_EF [m]
#  - ✅ Z_IN [m]
#  - ✅ beta_sun [deg]
#  - ✅ h_ell [m]
#  - ✅ is_man_or_missing
#  - ⚪️ is_maneuver_unresolved
#  - ⚪️ is_maneuver_unresolved_10m_decay
#  - ✅ lat_ell [deg]
#  - ✅ lat_sph [deg]
#  - ✅ lon_ell [deg]
#  - ✅ lon_sph [deg]
#  - ⚪️ mean_altitude_c
#  - ⚪️ orbital_decay_c
#  - ✅ r [m]
#  - ⚪️ res_c
#  - ⚪️ res_std_c
#  - ⚪️ residual_c
#  - ⚪️ se_orbital_decay_c
#  - ⚪️ se_slope
#  - ⚪️ seasonal_1_c
#  - ⚪️ seasonal_2_c
#  - ⚪️ seasonal_3_c
#  - ⚪️ seasonal_4_c
#  - ⚪️ trend_c
#  - ✅ u_sat [deg]
#  - ✅ u_sun [deg]
#  - ⚪️ unresolved_c
